# %%
import torch
import torchvision
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.transforms import ToTensor
from PIL import Image
import numpy as np
import cv2

# Load the fine-tuned model
model = fasterrcnn_resnet50_fpn(pretrained=False)
num_classes = 2  # 1 class (car) + background
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = torchvision.models.detection.faster_rcnn.FastRCNNPredictor(in_features, num_classes)
model.load_state_dict(torch.load("faster_rcnn_finetuned.pth"))
model.to("cuda")
model.eval()

# Video input and output paths
input_video_path = "3978613-hd_1920_1080_24fps.mp4"  # Replace with your video path
output_video_path = "output_video_with_boxes.mp4"

# Open the input video
cap = cv2.VideoCapture(input_video_path)
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

# Define the codec and create VideoWriter object to save the output video
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for MP4
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

# Process each frame
frame_count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    
    frame_count += 1
    print(f"Processing frame {frame_count}/{total_frames}")

    # Convert frame (numpy array) to PIL image
    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    pil_img = Image.fromarray(frame_rgb)
    img_tensor = ToTensor()(pil_img)
    img_tensor = img_tensor.unsqueeze(0).to("cuda")  # Add batch dimension and move to GPU

    # Perform inference
    with torch.no_grad():
        prediction = model(img_tensor)  # Prediction is already on GPU

    # Process predictions (move tensors to CPU for numpy conversion)
    boxes = prediction[0]['boxes'].cpu().numpy()
    labels = prediction[0]['labels'].cpu().numpy()
    scores = prediction[0]['scores'].cpu().numpy()

    # Draw bounding boxes on the frame
    confidence_threshold = 0.5
    for box, label, score in zip(boxes, labels, scores):
        if score > confidence_threshold:
            x_min, y_min, x_max, y_max = map(int, box)
            # Draw rectangle
            cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (0, 0, 255), 2)  # Red box
            # Add label and score
            label_text = f"{'car' if label == 1 else 'background'} ({score:.2f})"
            cv2.putText(frame, label_text, (x_min, y_min - 10), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

    # Write the frame to the output video
    out.write(frame)

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()
print(f"Video processing complete. Output saved as {output_video_path}")
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_18804\3228575740.py:14: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("faster_rcnn_finetuned.pth"))
# Processing frame 1/381
# Processing frame 2/381
# Processing frame 3/381
# Processing frame 4/381
# Processing frame 5/381
# Processing frame 6/381
# Processing frame 7/381
# Processing frame 8/381
# Processing frame 9/381
# Processing frame 10/381
# Processing frame 11/381
# Processing frame 12/381
# Processing frame 13/381
# Processing frame 14/381
# Processing frame 15/381
# Processing frame 16/381
# Processing frame 17/381
# Processing frame 18/381
# Processing frame 19/381
# Processing frame 20/381
# Processing frame 21/381
# Processing frame 22/381
# Processing frame 23/381
# Processing frame 24/381
# Processing frame 25/381
# Processing frame 26/381
# Processing frame 27/381
# Processing frame 28/381
# Processing frame 29/381
# Processing frame 30/381
# Processing frame 31/381
# Processing frame 32/381
# Processing frame 33/381
# Processing frame 34/381
# Processing frame 35/381
# Processing frame 36/381
# Processing frame 37/381
# Processing frame 38/381
# Processing frame 39/381
# Processing frame 40/381
# Processing frame 41/381
# Processing frame 42/381
# Processing frame 43/381
# Processing frame 44/381
# Processing frame 45/381
# Processing frame 46/381
# Processing frame 47/381
# Processing frame 48/381
# Processing frame 49/381
# Processing frame 50/381
# Processing frame 51/381
# Processing frame 52/381
# Processing frame 53/381
# Processing frame 54/381
# Processing frame 55/381
# Processing frame 56/381
# Processing frame 57/381
# Processing frame 58/381
# Processing frame 59/381
# Processing frame 60/381
# Processing frame 61/381
# Processing frame 62/381
# Processing frame 63/381
# Processing frame 64/381
# Processing frame 65/381
# Processing frame 66/381
# Processing frame 67/381
# Processing frame 68/381
# Processing frame 69/381
# Processing frame 70/381
# Processing frame 71/381
# Processing frame 72/381
# Processing frame 73/381
# Processing frame 74/381
# Processing frame 75/381
# Processing frame 76/381
# Processing frame 77/381
# Processing frame 78/381
# Processing frame 79/381
# Processing frame 80/381
# Processing frame 81/381
# Processing frame 82/381
# Processing frame 83/381
# Processing frame 84/381
# Processing frame 85/381
# Processing frame 86/381
# Processing frame 87/381
# Processing frame 88/381
# Processing frame 89/381
# Processing frame 90/381
# Processing frame 91/381
# Processing frame 92/381
# Processing frame 93/381
# Processing frame 94/381
# Processing frame 95/381
# Processing frame 96/381
# Processing frame 97/381
# Processing frame 98/381
# Processing frame 99/381
# Processing frame 100/381
# Processing frame 101/381
# Processing frame 102/381
# Processing frame 103/381
# Processing frame 104/381
# Processing frame 105/381
# Processing frame 106/381
# Processing frame 107/381
# Processing frame 108/381
# Processing frame 109/381
# Processing frame 110/381
# Processing frame 111/381
# Processing frame 112/381
# Processing frame 113/381
# Processing frame 114/381
# Processing frame 115/381
# Processing frame 116/381
# Processing frame 117/381
# Processing frame 118/381
# Processing frame 119/381
# Processing frame 120/381
# Processing frame 121/381
# Processing frame 122/381
# Processing frame 123/381
# Processing frame 124/381
# Processing frame 125/381
# Processing frame 126/381
# Processing frame 127/381
# Processing frame 128/381
# Processing frame 129/381
# Processing frame 130/381
# Processing frame 131/381
# Processing frame 132/381
# Processing frame 133/381
# Processing frame 134/381
# Processing frame 135/381
# Processing frame 136/381
# Processing frame 137/381
# Processing frame 138/381
# Processing frame 139/381
# Processing frame 140/381
# Processing frame 141/381
# Processing frame 142/381
# Processing frame 143/381
# Processing frame 144/381
# Processing frame 145/381
# Processing frame 146/381
# Processing frame 147/381
# Processing frame 148/381
# Processing frame 149/381
# Processing frame 150/381
# Processing frame 151/381
# Processing frame 152/381
# Processing frame 153/381
# Processing frame 154/381
# Processing frame 155/381
# Processing frame 156/381
# Processing frame 157/381
# Processing frame 158/381
# Processing frame 159/381
# Processing frame 160/381
# Processing frame 161/381
# Processing frame 162/381
# Processing frame 163/381
# Processing frame 164/381
# Processing frame 165/381
# Processing frame 166/381
# Processing frame 167/381
# Processing frame 168/381
# Processing frame 169/381
# Processing frame 170/381
# Processing frame 171/381
# Processing frame 172/381
# Processing frame 173/381
# Processing frame 174/381
# Processing frame 175/381
# Processing frame 176/381
# Processing frame 177/381
# Processing frame 178/381
# Processing frame 179/381
# Processing frame 180/381
# Processing frame 181/381
# Processing frame 182/381
# Processing frame 183/381
# Processing frame 184/381
# Processing frame 185/381
# Processing frame 186/381
# Processing frame 187/381
# Processing frame 188/381
# Processing frame 189/381
# Processing frame 190/381
# Processing frame 191/381
# Processing frame 192/381
# Processing frame 193/381
# Processing frame 194/381
# Processing frame 195/381
# Processing frame 196/381
# Processing frame 197/381
# Processing frame 198/381
# Processing frame 199/381
# Processing frame 200/381
# Processing frame 201/381
# Processing frame 202/381
# Processing frame 203/381
# Processing frame 204/381
# Processing frame 205/381
# Processing frame 206/381
# Processing frame 207/381
# Processing frame 208/381
# Processing frame 209/381
# Processing frame 210/381
# Processing frame 211/381
# Processing frame 212/381
# Processing frame 213/381
# Processing frame 214/381
# Processing frame 215/381
# Processing frame 216/381
# Processing frame 217/381
# Processing frame 218/381
# Processing frame 219/381
# Processing frame 220/381
# Processing frame 221/381
# Processing frame 222/381
# Processing frame 223/381
# Processing frame 224/381
# Processing frame 225/381
# Processing frame 226/381
# Processing frame 227/381
# Processing frame 228/381
# Processing frame 229/381
# Processing frame 230/381
# Processing frame 231/381
# Processing frame 232/381
# Processing frame 233/381
# Processing frame 234/381
# Processing frame 235/381
# Processing frame 236/381
# Processing frame 237/381
# Processing frame 238/381
# Processing frame 239/381
# Processing frame 240/381
# Processing frame 241/381
# Processing frame 242/381
# Processing frame 243/381
# Processing frame 244/381
# Processing frame 245/381
# Processing frame 246/381
# Processing frame 247/381
# Processing frame 248/381
# Processing frame 249/381
# Processing frame 250/381
# Processing frame 251/381
# Processing frame 252/381
# Processing frame 253/381
# Processing frame 254/381
# Processing frame 255/381
# Processing frame 256/381
# Processing frame 257/381
# Processing frame 258/381
# Processing frame 259/381
# Processing frame 260/381
# Processing frame 261/381
# Processing frame 262/381
# Processing frame 263/381
# Processing frame 264/381
# Processing frame 265/381
# Processing frame 266/381
# Processing frame 267/381
# Processing frame 268/381
# Processing frame 269/381
# Processing frame 270/381
# Processing frame 271/381
# Processing frame 272/381
# Processing frame 273/381
# Processing frame 274/381
# Processing frame 275/381
# Processing frame 276/381
# Processing frame 277/381
# Processing frame 278/381
# Processing frame 279/381
# Processing frame 280/381
# Processing frame 281/381
# Processing frame 282/381
# Processing frame 283/381
# Processing frame 284/381
# Processing frame 285/381
# Processing frame 286/381
# Processing frame 287/381
# Processing frame 288/381
# Processing frame 289/381
# Processing frame 290/381
# Processing frame 291/381
# Processing frame 292/381
# Processing frame 293/381
# Processing frame 294/381
# Processing frame 295/381
# Processing frame 296/381
# Processing frame 297/381
# Processing frame 298/381
# Processing frame 299/381
# Processing frame 300/381
# Processing frame 301/381
# Processing frame 302/381
# Processing frame 303/381
# Processing frame 304/381
# Processing frame 305/381
# Processing frame 306/381
# Processing frame 307/381
# Processing frame 308/381
# Processing frame 309/381
# Processing frame 310/381
# Processing frame 311/381
# Processing frame 312/381
# Processing frame 313/381
# Processing frame 314/381
# Processing frame 315/381
# Processing frame 316/381
# Processing frame 317/381
# Processing frame 318/381
# Processing frame 319/381
# Processing frame 320/381
# Processing frame 321/381
# Processing frame 322/381
# Processing frame 323/381
# Processing frame 324/381
# Processing frame 325/381
# Processing frame 326/381
# Processing frame 327/381
# Processing frame 328/381
# Processing frame 329/381
# Processing frame 330/381
# Processing frame 331/381
# Processing frame 332/381
# Processing frame 333/381
# Processing frame 334/381
# Processing frame 335/381
# Processing frame 336/381
# Processing frame 337/381
# Processing frame 338/381
# Processing frame 339/381
# Processing frame 340/381
# Processing frame 341/381
# Processing frame 342/381
# Processing frame 343/381
# Processing frame 344/381
# Processing frame 345/381
# Processing frame 346/381
# Processing frame 347/381
# Processing frame 348/381
# Processing frame 349/381
# Processing frame 350/381
# Processing frame 351/381
# Processing frame 352/381
# Processing frame 353/381
# Processing frame 354/381
# Processing frame 355/381
# Processing frame 356/381
# Processing frame 357/381
# Processing frame 358/381
# Processing frame 359/381
# Processing frame 360/381
# Processing frame 361/381
# Processing frame 362/381
# Processing frame 363/381
# Processing frame 364/381
# Processing frame 365/381
# Processing frame 366/381
# Processing frame 367/381
# Processing frame 368/381
# Processing frame 369/381
# Processing frame 370/381
# Processing frame 371/381
# Processing frame 372/381
# Processing frame 373/381
# Processing frame 374/381
# Processing frame 375/381
# Processing frame 376/381
# Processing frame 377/381
# Processing frame 378/381
# Processing frame 379/381
# Processing frame 380/381
# Processing frame 381/381
# Video processing complete. Output saved as output_video_with_boxes.mp4
